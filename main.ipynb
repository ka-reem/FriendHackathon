# %%
pip install fastapi jinja2 modal multion notion-client sqlalchemy openai pydantic
# Out:
# Requirement already satisfied: fastapi in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (0.112.0)
# Requirement already satisfied: jinja2 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: modal in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (0.64.15)
# Collecting multion
#   Obtaining dependency information for multion from https://files.pythonhosted.org/packages/c1/01/e350dd5f12174c81b9b57dd3ee9bdb0d5125cf9332b9319596d792198140/multion-1.3.6-py3-none-any.whl.metadata
#   Downloading multion-1.3.6-py3-none-any.whl.metadata (5.0 kB)
# Collecting notion-client
#   Obtaining dependency information for notion-client from https://files.pythonhosted.org/packages/22/5e/977505b17c5528cffaaf561de46f58fa546345ae75866e3985039aaa991d/notion_client-2.2.1-py2.py3-none-any.whl.metadata
#   Downloading notion_client-2.2.1-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (1.4.39)
# Collecting openai
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/7c/ae/2a66f072b9733b3287807f76bca53913aa448c7ac1d70b08cd9e79af7675/openai-1.40.3-py3-none-any.whl.metadata
#   Downloading openai-1.40.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pydantic in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (2.8.2)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from fastapi) (0.37.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from jinja2) (2.1.1)
# Requirement already satisfied: aiohttp in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (3.10.3)
# Requirement already satisfied: aiostream~=0.5.2 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (0.5.2)
# Requirement already satisfied: certifi in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (2023.7.22)
# Requirement already satisfied: click>=8.1.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (8.1.7)
# Requirement already satisfied: grpclib==0.4.7 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (0.4.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0,>=3.19 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (4.23.4)
# Requirement already satisfied: rich>=12.0.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (13.5.1)
# Requirement already satisfied: synchronicity~=0.6.6 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (0.6.7)
# Requirement already satisfied: toml in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (0.10.2)
# Requirement already satisfied: typer>=0.9 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (0.12.3)
# Requirement already satisfied: types-certifi in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (2021.10.8.3)
# Requirement already satisfied: types-toml in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (0.10.8.20240310)
# Requirement already satisfied: watchfiles in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from modal) (0.23.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from grpclib==0.4.7->modal) (4.1.0)
# Requirement already satisfied: multidict in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from grpclib==0.4.7->modal) (6.0.5)
# Collecting agentops<0.3.0,>=0.2.3 (from multion)
#   Obtaining dependency information for agentops<0.3.0,>=0.2.3 from https://files.pythonhosted.org/packages/5a/f2/f90538b00d887c04a5570e8a3af4aef27a600a67c058a0ee6befafd60748/agentops-0.2.6-py3-none-any.whl.metadata
#   Downloading agentops-0.2.6-py3-none-any.whl.metadata (12 kB)
# Collecting httpx>=0.21.2 (from multion)
#   Obtaining dependency information for httpx>=0.21.2 from https://files.pythonhosted.org/packages/41/7b/ddacf6dcebb42466abd03f368782142baa82e08fc0c1f8eaa05b4bae87d5/httpx-0.27.0-py3-none-any.whl.metadata
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting httpx-sse==0.4.0 (from multion)
#   Obtaining dependency information for httpx-sse==0.4.0 from https://files.pythonhosted.org/packages/e1/9b/a181f281f65d776426002f330c31849b86b31fc9d848db62e16f03ff739f/httpx_sse-0.4.0-py3-none-any.whl.metadata
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from openai) (3.5.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Obtaining dependency information for jiter<1,>=0.4.0 from https://files.pythonhosted.org/packages/07/2d/5bdaddfefc44f91af0f3340e75ef327950d790c9f86490757ac8b395c074/jiter-0.5.0-cp310-cp310-macosx_11_0_arm64.whl.metadata
#   Downloading jiter-0.5.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Requirement already satisfied: sniffio in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from openai) (4.64.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from pydantic) (2.20.1)
# Collecting requests==2.31.0 (from agentops<0.3.0,>=0.2.3->multion)
#   Obtaining dependency information for requests==2.31.0 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting psutil==5.9.8 (from agentops<0.3.0,>=0.2.3->multion)
#   Obtaining dependency information for psutil==5.9.8 from https://files.pythonhosted.org/packages/05/33/2d74d588408caedd065c2497bdb5ef83ce6082db01289a1e1147f6639802/psutil-5.9.8-cp38-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading psutil-5.9.8-cp38-abi3-macosx_11_0_arm64.whl.metadata (21 kB)
# Collecting packaging==23.2 (from agentops<0.3.0,>=0.2.3->multion)
#   Obtaining dependency information for packaging==23.2 from https://files.pythonhosted.org/packages/ec/1a/610693ac4ee14fcdf2d9bf3c493370e4f2ef7ae2e19217d7a237ff42367d/packaging-23.2-py3-none-any.whl.metadata
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting termcolor==2.4.0 (from agentops<0.3.0,>=0.2.3->multion)
#   Obtaining dependency information for termcolor==2.4.0 from https://files.pythonhosted.org/packages/d9/5f/8c716e47b3a50cbd7c146f45881e11d9414def768b7cd9c5e6650ec2a80a/termcolor-2.4.0-py3-none-any.whl.metadata
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from requests==2.31.0->agentops<0.3.0,>=0.2.3->multion) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from requests==2.31.0->agentops<0.3.0,>=0.2.3->multion) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from requests==2.31.0->agentops<0.3.0,>=0.2.3->multion) (1.26.14)
# Collecting httpcore==1.* (from httpx>=0.21.2->multion)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/78/d4/e5d7e4f2174f8a4d63c8897d79eb8fe2503f7ecc03282fee1fa2719c2704/httpcore-1.0.5-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.21.2->multion)
#   Obtaining dependency information for h11<0.15,>=0.13 from https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl.metadata
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from rich>=12.0.0->modal) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from rich>=12.0.0->modal) (2.15.1)
# Requirement already satisfied: sigtools==4.0.1 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from synchronicity~=0.6.6->modal) (4.0.1)
# Requirement already satisfied: attrs in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from sigtools==4.0.1->synchronicity~=0.6.6->modal) (23.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from typer>=0.9->modal) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from aiohttp->modal) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from aiohttp->modal) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from aiohttp->modal) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from aiohttp->modal) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from aiohttp->modal) (4.0.3)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from h2<5,>=3.1.0->grpclib==0.4.7->modal) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from h2<5,>=3.1.0->grpclib==0.4.7->modal) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/kareemamin/anaconda3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->modal) (0.1.2)
# Downloading multion-1.3.6-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.3 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading notion_client-2.2.1-py2.py3-none-any.whl (13 kB)
# Downloading openai-1.40.3-py3-none-any.whl (360 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading agentops-0.2.6-py3-none-any.whl (37 kB)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.9 MB/s eta 0:00:00
# Downloading psutil-5.9.8-cp38-abi3-macosx_11_0_arm64.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading jiter-0.5.0-cp310-cp310-macosx_11_0_arm64.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.3/299.3 kB 4.6 MB/s eta 0:00:0000:01:00:01
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: termcolor, requests, psutil, packaging, jiter, httpx-sse, h11, distro, httpcore, agentops, httpx, openai, notion-client, multion
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.3.0
#     Uninstalling termcolor-2.3.0:
#       Successfully uninstalled termcolor-2.3.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.0
#     Uninstalling psutil-5.9.0:
#       Successfully uninstalled psutil-5.9.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 22.0
#     Uninstalling packaging-22.0:
#       Successfully uninstalled packaging-22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# spyder 5.4.1 requires pyqt5<5.16, which is not installed.
# spyder 5.4.1 requires pyqtwebengine<5.16, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.31.0 which is incompatible.
# tensorflow-macos 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed agentops-0.2.6 distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 httpx-sse-0.4.0 jiter-0.5.0 multion-1.3.6 notion-client-2.2.1 openai-1.40.3 packaging-23.2 psutil-5.9.8 requests-2.31.0 termcolor-2.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
conda deactivate
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda deactivate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from typing import List

from fastapi import FastAPI, HTTPException, Request, Form
from fastapi.responses import HTMLResponse
from fastapi.templating import Jinja2Templates
from modal import Image, App, Secret, asgi_app, mount
from multion.client import MultiOn

import templates
from db import get_notion_crm_api_key, get_notion_database_id, store_notion_crm_api_key, store_notion_database_id, \
    clean_all_transcripts_except, append_segment_to_transcript, remove_transcript
from llm import news_checker
from models import Memory
from notion_utils import store_memoy_in_db

app = FastAPI()

modal_app = App(
    name='plugins_examples',
    secrets=[Secret.from_dotenv('.env')],
    mounts=[
        mount.Mount.from_local_dir('templates/', remote_path='templates/'),
    ]
)

multion = MultiOn(api_key=os.getenv('MULTION_API_KEY', '123'))


@modal_app.function(
    image=Image.debian_slim().pip_install_from_requirements('requirements.txt'),
    keep_warm=1,  # need 7 for 1rps
    memory=(1024, 2048),
    cpu=4,
    allow_concurrent_inputs=10,
)
@asgi_app()
def plugins_app():
    return app


def call_multion(books: List[str]):
    print('Buying books with MultiOn')
    response = multion.browse(
        cmd=f"Add to my cart the following books (in paperback version, or any physical version): {books}",
        url="https://amazon.com",
        local=True,
    )
    return response.message


# **************************************************
# ************ On Memory Created Plugin ************
# **************************************************

# noinspection PyRedeclaration
templates = Jinja2Templates(directory="templates")


@app.get('/setup-notion-crm', response_class=HTMLResponse)
async def setup_notion_crm(request: Request, uid: str):
    if not uid:
        raise HTTPException(status_code=400, detail='UID is required')
    return templates.TemplateResponse("setup_notion_crm.html", {"request": request, "uid": uid})


@app.post('/creds/notion-crm', response_class=HTMLResponse)
def creds_notion_crm(request: Request, uid: str = Form(...), api_key: str = Form(...), database_id: str = Form(...)):
    if not api_key or not database_id:
        raise HTTPException(status_code=400, detail='API Key and Database ID are required')
    print({'uid': uid, 'api_key': api_key, 'database_id': database_id})
    store_notion_crm_api_key(uid, api_key)
    store_notion_database_id(uid, database_id)
    return templates.TemplateResponse("okpage.html", {"request": request, "uid": uid})


@app.get('/setup/notion-crm')
def is_setup_completed(uid: str):
    notion_api_key = get_notion_crm_api_key(uid)
    notion_database_id = get_notion_database_id(uid)
    return {'is_setup_completed': notion_api_key is not None and notion_database_id is not None}


@app.post('/notion-crm')
def notion_crm(memory: Memory, uid: str):
    print(memory.dict())
    notion_api_key = get_notion_crm_api_key(uid)
    if not notion_api_key:
        return {'message': 'Your Notion CRM plugin is not setup properly. Check your plugin settings.'}

    store_memoy_in_db(notion_api_key, get_notion_database_id(uid), memory)
    return {}


# *******************************************************
# ************ On Transcript Received Plugin ************
# *******************************************************


@app.post('/news-checker')
def news_checker_endpoint(uid: str, data: dict):
    session_id = data['session_id']  # use session id in case your plugin needs the whole conversation context
    new_segments = data['segments']
    clean_all_transcripts_except(uid, session_id)

    transcript: list[dict] = append_segment_to_transcript(uid, session_id, new_segments)
    message = news_checker(transcript)

    if message:
        # so that in the next call with already triggered stuff, it doesn't trigger again
        remove_transcript(uid, session_id)

    return {'message': message}

# https://e604-107-3-134-29.ngrok-free.app/news-checker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 11
#       8 from multion.client import MultiOn
#      10 import templates
# ---> 11 from db import get_notion_crm_api_key, get_notion_database_id, store_notion_crm_api_key, store_notion_database_id, \
#      12     clean_all_transcripts_except, append_segment_to_transcript, remove_transcript
#      13 from llm import news_checker
#      14 from models import Memory
#
# ModuleNotFoundError: No module named 'db'
